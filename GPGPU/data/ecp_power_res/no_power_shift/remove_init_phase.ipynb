# %%
import pandas as pd

# %%
def remove_init(path):
    # Load your GPU and CPU CSV files into dataframes
    gpu_df = pd.read_csv(path + 'bert_large_power_gpu.csv')
    cpu_df = pd.read_csv(path + "bert_large_power_cpu.csv")
    
    # Step 1: GPU - Find the first set of 5 continuous rows where GPU power > 150
    for i in range(len(gpu_df) - 7):
       
        if all(gpu_df['GPU 0 Power (W)'].iloc[i:i+7] > 140):
            gpu_threshold_row = gpu_df.iloc[i]
            t0 = gpu_threshold_row['Time (s)']
            break
    
    # Delete rows above t0
    gpu_df = gpu_df[gpu_df['Time (s)'] >= t0]
    
    # Adjust Time (s) in GPU file
    gpu_df['Time (s)'] = gpu_df['Time (s)'] - t0
    
    # Step 2: CPU - Find the first row where Time (s) >= t0
    cpu_threshold_row = cpu_df[cpu_df['Time (s)'] >= t0].iloc[0]
    r1_time = cpu_threshold_row['Time (s)']
    
    # Delete rows above r1
    cpu_df = cpu_df[cpu_df['Time (s)'] >= r1_time]
    
    # Adjust Time (s) in CPU file
    cpu_df['Time (s)'] = cpu_df['Time (s)'] - r1_time
    
    # Save the modified files if needed
    gpu_df.to_csv(path + 'bert_large2_power_gpu.csv', index=False)
    cpu_df.to_csv(path + "bert_large2_power_cpu.csv", index=False)

remove_init("./dynamic_uncore/" )
# remove_init("./max_uncore/" )
# remove_init("./min_uncore/" )

# %%
def remove_init(path):
    # Load your GPU and CPU CSV files into dataframes
    gpu_df = pd.read_csv(path + 'Resnet50_power_gpu.csv')
    cpu_df = pd.read_csv(path + "Resnet50_power_cpu.csv")
    
    # Step 1: GPU - Find the first set of 5 continuous rows where GPU power > 150
    for i in range(len(gpu_df) - 4):
        # Check if 5 continuous rows have GPU power greater than 150
        if all(gpu_df['GPU 0 Power (W)'].iloc[i:i+15] > 140):
            gpu_threshold_row = gpu_df.iloc[i]
            t0 = gpu_threshold_row['Time (s)']
            break
    
    # Delete rows above t0
    gpu_df = gpu_df[gpu_df['Time (s)'] >= t0]
    
    # Adjust Time (s) in GPU file
    gpu_df['Time (s)'] = gpu_df['Time (s)'] - t0
    
    # Step 2: CPU - Find the first row where Time (s) >= t0
    cpu_threshold_row = cpu_df[cpu_df['Time (s)'] >= t0].iloc[0]
    r1_time = cpu_threshold_row['Time (s)']
    
    # Delete rows above r1
    cpu_df = cpu_df[cpu_df['Time (s)'] >= r1_time]
    
    # Adjust Time (s) in CPU file
    cpu_df['Time (s)'] = cpu_df['Time (s)'] - r1_time
    
    # Save the modified files if needed
    gpu_df.to_csv(path + 'Resnet50_2_power_gpu.csv', index=False)
    cpu_df.to_csv(path + "Resnet50_2_power_cpu.csv", index=False)
    
remove_init("./dynamic_uncore/" )
# remove_init("./max_uncore/" )
# remove_init("./min_uncore/" )

# %%
def remove_init(path):
    # Load your GPU and CPU CSV files into dataframes
    gpu_df = pd.read_csv(path + 'bert_large_power_gpu_ups.csv')
    cpu_df = pd.read_csv(path + "bert_large_power_cpu_ups.csv")
    
    # Step 1: GPU - Find the first set of 5 continuous rows where GPU power > 150
    for i in range(len(gpu_df) - 7):
       
        if all(gpu_df['GPU 0 Power (W)'].iloc[i:i+7] > 100):
            gpu_threshold_row = gpu_df.iloc[i]
            t0 = gpu_threshold_row['Time (s)']
            break
    
    # Delete rows above t0
    gpu_df = gpu_df[gpu_df['Time (s)'] >= t0]
    
    # Adjust Time (s) in GPU file
    gpu_df['Time (s)'] = gpu_df['Time (s)'] - t0
    
    # Step 2: CPU - Find the first row where Time (s) >= t0
    cpu_threshold_row = cpu_df[cpu_df['Time (s)'] >= t0].iloc[0]
    r1_time = cpu_threshold_row['Time (s)']
    
    # Delete rows above r1
    cpu_df = cpu_df[cpu_df['Time (s)'] >= r1_time]
    
    # Adjust Time (s) in CPU file
    cpu_df['Time (s)'] = cpu_df['Time (s)'] - r1_time
    
    # Save the modified files if needed
    gpu_df.to_csv(path + 'bert_large2_power_gpu_ups.csv', index=False)
    cpu_df.to_csv(path + "bert_large2_power_cpu_ups.csv", index=False)

remove_init("./ups_uncore/" )

# %%
def remove_init(path):
    # Load your GPU and CPU CSV files into dataframes
    gpu_df = pd.read_csv(path + 'Resnet50_power_gpu_ups.csv')
    cpu_df = pd.read_csv(path + "Resnet50_power_cpu_ups.csv")
    
    # Step 1: GPU - Find the first set of 5 continuous rows where GPU power > 150
    for i in range(len(gpu_df) - 7):
       
        if all(gpu_df['GPU 0 Power (W)'].iloc[i:i+15] > 140):
            gpu_threshold_row = gpu_df.iloc[i]
            t0 = gpu_threshold_row['Time (s)']
            break
    
    # Delete rows above t0
    gpu_df = gpu_df[gpu_df['Time (s)'] >= t0]
    
    # Adjust Time (s) in GPU file
    gpu_df['Time (s)'] = gpu_df['Time (s)'] - t0
    
    # Step 2: CPU - Find the first row where Time (s) >= t0
    cpu_threshold_row = cpu_df[cpu_df['Time (s)'] >= t0].iloc[0]
    r1_time = cpu_threshold_row['Time (s)']
    
    # Delete rows above r1
    cpu_df = cpu_df[cpu_df['Time (s)'] >= r1_time]
    
    # Adjust Time (s) in CPU file
    cpu_df['Time (s)'] = cpu_df['Time (s)'] - r1_time
    
    # Save the modified files if needed
    gpu_df.to_csv(path + 'Resnet50_2_power_gpu_ups.csv', index=False)
    cpu_df.to_csv(path + "Resnet50_2_power_cpu_ups.csv", index=False)

remove_init("./ups_uncore/" )

# %%
def remove_init(path):
    # Load your GPU and CPU CSV files into dataframes
    gpu_df = pd.read_csv(path + 'bert_large_power_gpu.csv')
    cpu_df = pd.read_csv(path + "bert_large_power_cpu.csv")
    
    # Step 1: GPU - Find the first set of 7 continuous rows where any GPU power > 100 for each row
    for i in range(len(gpu_df) - 7):
        if all((gpu_df.iloc[i:i+7][['GPU 0 Power (W)', 'GPU 1 Power (W)', 'GPU 2 Power (W)', 'GPU 3 Power (W)']] > 140).any(axis=1)):
            gpu_threshold_row = gpu_df.iloc[i]
            t0 = gpu_threshold_row['Time (s)']
            break
    
    # Delete rows above t0
    gpu_df = gpu_df[gpu_df['Time (s)'] >= t0]
    
    # Adjust Time (s) in GPU file
    gpu_df['Time (s)'] = gpu_df['Time (s)'] - t0
    
    # Step 2: CPU - Find the first row where Time (s) >= t0
    cpu_threshold_row = cpu_df[cpu_df['Time (s)'] >= t0].iloc[0]
    r1_time = cpu_threshold_row['Time (s)']
    
    # Delete rows above r1
    cpu_df = cpu_df[cpu_df['Time (s)'] >= r1_time]
    
    # Adjust Time (s) in CPU file
    cpu_df['Time (s)'] = cpu_df['Time (s)'] - r1_time
    
    # Save the modified files if needed
    gpu_df.to_csv(path + 'bert_large2_power_gpu.csv', index=False)
    cpu_df.to_csv(path + "bert_large2_power_cpu.csv", index=False)

remove_init("./multiGPU/max_uncore/")
remove_init("./multiGPU/min_uncore/")
remove_init("./multiGPU/dynamic_uncore/")

# %%
def remove_init(path):
    # Load your GPU and CPU CSV files into dataframes
    gpu_df = pd.read_csv(path + 'Resnet50_power_gpu.csv')
    cpu_df = pd.read_csv(path + "Resnet50_power_cpu.csv")
    
    # Step 1: GPU - Find the first set of 7 continuous rows where the average power of all four GPUs > 90
    for i in range(len(gpu_df) - 7):
        # Calculate the average power of all four GPUs for 7 continuous rows
        avg_power = gpu_df.iloc[i:i+7][['GPU 0 Power (W)', 'GPU 1 Power (W)', 'GPU 2 Power (W)', 'GPU 3 Power (W)']].mean(axis=1)
        
        # Check if the average power is greater than 90 for all 7 rows
        if all(avg_power > 120):
            gpu_threshold_row = gpu_df.iloc[i]
            t0 = gpu_threshold_row['Time (s)']
            break
    
    # Delete rows above t0
    gpu_df = gpu_df[gpu_df['Time (s)'] >= t0]
    
    # Adjust Time (s) in GPU file
    gpu_df['Time (s)'] = gpu_df['Time (s)'] - t0
    
    # Step 2: CPU - Find the first row where Time (s) >= t0
    cpu_threshold_row = cpu_df[cpu_df['Time (s)'] >= t0].iloc[0]
    r1_time = cpu_threshold_row['Time (s)']
    
    # Delete rows above r1
    cpu_df = cpu_df[cpu_df['Time (s)'] >= r1_time]
    
    # Adjust Time (s) in CPU file
    cpu_df['Time (s)'] = cpu_df['Time (s)'] - r1_time
    
    # Save the modified files if needed
    gpu_df.to_csv(path + 'Resnet50_2_power_gpu.csv', index=False)
    cpu_df.to_csv(path + "Resnet50_2_power_cpu.csv", index=False)

remove_init("./multiGPU/max_uncore/")
remove_init("./multiGPU/min_uncore/")
remove_init("./multiGPU/dynamic_uncore/")

# %%
def remove_init(path):
    # Load your GPU and CPU CSV files into dataframes
    gpu_df = pd.read_csv(path + 'bert_large_power_gpu_ups.csv')
    cpu_df = pd.read_csv(path + "bert_large_power_cpu_ups.csv")
    
    # Step 1: GPU - Find the first set of 7 continuous rows where any GPU power > 100 for each row
    for i in range(len(gpu_df) - 7):
        if all((gpu_df.iloc[i:i+7][['GPU 0 Power (W)', 'GPU 1 Power (W)', 'GPU 2 Power (W)', 'GPU 3 Power (W)']] > 140).any(axis=1)):
            gpu_threshold_row = gpu_df.iloc[i]
            t0 = gpu_threshold_row['Time (s)']
            break
    
    # Delete rows above t0
    gpu_df = gpu_df[gpu_df['Time (s)'] >= t0]
    
    # Adjust Time (s) in GPU file
    gpu_df['Time (s)'] = gpu_df['Time (s)'] - t0
    
    # Step 2: CPU - Find the first row where Time (s) >= t0
    cpu_threshold_row = cpu_df[cpu_df['Time (s)'] >= t0].iloc[0]
    r1_time = cpu_threshold_row['Time (s)']
    
    # Delete rows above r1
    cpu_df = cpu_df[cpu_df['Time (s)'] >= r1_time]
    
    # Adjust Time (s) in CPU file
    cpu_df['Time (s)'] = cpu_df['Time (s)'] - r1_time
    
    # Save the modified files if needed
    gpu_df.to_csv(path + 'bert_large2_power_gpu_ups.csv', index=False)
    cpu_df.to_csv(path + "bert_large2_power_cpu_ups.csv", index=False)

remove_init("./multiGPU/ups_uncore/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 34
#      31     cpu_df.to_csv(path + "bert_large2_power_cpu_ups.csv", index=False)
#      33 remove_init("./multiGPU/ups_uncore/")
# ---> 34 remove_init("./multiGPU/max_uncore/")
#      35 remove_init("./multiGPU/min_uncore/")
#      36 remove_init("./multiGPU/dynamic_uncore/")
#
# Cell In[2], line 3, in remove_init(path)
#       1 def remove_init(path):
#       2     # Load your GPU and CPU CSV files into dataframes
# ----> 3     gpu_df = pd.read_csv(path + 'bert_large_power_gpu_ups.csv')
#       4     cpu_df = pd.read_csv(path + "bert_large_power_cpu_ups.csv")
#       6     # Step 1: GPU - Find the first set of 7 continuous rows where any GPU power > 100 for each row
#
# File /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /usr/local/lib/python3.10/dist-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './multiGPU/max_uncore/bert_large_power_gpu_ups.csv'

# %%
def remove_init(path):
    # Load your GPU and CPU CSV files into dataframes
    gpu_df = pd.read_csv(path + 'Resnet50_power_gpu_ups.csv')
    cpu_df = pd.read_csv(path + "Resnet50_power_cpu_ups.csv")
    
    # Step 1: GPU - Find the first set of 7 continuous rows where the average power of all four GPUs > 90
    for i in range(len(gpu_df) - 7):
        # Calculate the average power of all four GPUs for 7 continuous rows
        avg_power = gpu_df.iloc[i:i+7][['GPU 0 Power (W)', 'GPU 1 Power (W)', 'GPU 2 Power (W)', 'GPU 3 Power (W)']].mean(axis=1)
        
        # Check if the average power is greater than 90 for all 7 rows
        if all(avg_power > 140):
            gpu_threshold_row = gpu_df.iloc[i]
            t0 = gpu_threshold_row['Time (s)']
            break
    
    # Delete rows above t0
    gpu_df = gpu_df[gpu_df['Time (s)'] >= t0]
    
    # Adjust Time (s) in GPU file
    gpu_df['Time (s)'] = gpu_df['Time (s)'] - t0
    
    # Step 2: CPU - Find the first row where Time (s) >= t0
    cpu_threshold_row = cpu_df[cpu_df['Time (s)'] >= t0].iloc[0]
    r1_time = cpu_threshold_row['Time (s)']
    
    # Delete rows above r1
    cpu_df = cpu_df[cpu_df['Time (s)'] >= r1_time]
    
    # Adjust Time (s) in CPU file
    cpu_df['Time (s)'] = cpu_df['Time (s)'] - r1_time
    
    # Save the modified files if needed
    gpu_df.to_csv(path + 'Resnet50_2_power_gpu_ups.csv', index=False)
    cpu_df.to_csv(path + "Resnet50_2_power_cpu_ups.csv", index=False)

remove_init("./multiGPU/ups_uncore/")
